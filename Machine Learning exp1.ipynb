# %%
import pandas as pd
df=pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
df
# Out:
#           ID                            Name Sex   Age  Height  Weight  \
# 0          1                       A Dijiang   M  24.0   180.0    80.0
# 1          2                        A Lamusi   M  23.0   170.0    60.0
# 2          3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3          4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4          5        Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...      ...                             ...  ..   ...     ...     ...
# 69995  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69996  35656              Stuart Fitzsimmons   M  19.0     NaN     NaN
# 69997  35657  David Thomas "Dave" Fitzsimons   M  26.0   170.0    65.0
# 69998  35657  David Thomas "Dave" Fitzsimons   M  30.0   170.0    65.0
# 69999  35658                    Marek Fiurek   M  23.0   180.0    68.0
#
#                  Team  NOC        Games  Year  Season       City  \
# 0               China  CHN  1992 Summer  1992  Summer  Barcelona
# 1               China  CHN  2012 Summer  2012  Summer     London
# 2             Denmark  DEN  1920 Summer  1920  Summer  Antwerpen
# 3      Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris
# 4         Netherlands  NED  1988 Winter  1988  Winter    Calgary
# ...               ...  ...          ...   ...     ...        ...
# 69995   Great Britain  GBR  1976 Winter  1976  Winter  Innsbruck
# 69996   Great Britain  GBR  1976 Winter  1976  Winter  Innsbruck
# 69997       Australia  AUS  1976 Summer  1976  Summer   Montreal
# 69998       Australia  AUS  1980 Summer  1980  Summer     Moskva
# 69999  Czech Republic  CZE  1998 Winter  1998  Winter     Nagano
#
#                  Sport                             Event Medal
# 0           Basketball       Basketball Men's Basketball   NaN
# 1                 Judo      Judo Men's Extra-Lightweight   NaN
# 2             Football           Football Men's Football   NaN
# 3           Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4        Speed Skating  Speed Skating Women's 500 metres   NaN
# ...                ...                               ...   ...
# 69995    Alpine Skiing  Alpine Skiing Men's Giant Slalom   NaN
# 69996    Alpine Skiing        Alpine Skiing Men's Slalom   NaN
# 69997        Athletics     Athletics Men's 10,000 metres   NaN
# 69998        Athletics      Athletics Men's 5,000 metres   NaN
# 69999  Nordic Combined        Nordic Combined Men's Team   NaN
#
# [70000 rows x 15 columns]

# %%
df.shape
# Out:
# (70000, 15)

# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# read the dataset
df=pd.read_csv('data.csv')

#get the location
X=df.iloc[:,:-1]
y=df.iloc[:,:-1]

#split the dataset

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.05,random_state=0)

X_train
# Out:
#           ID                                      Name Sex   Age  Height  \
# 21410  11300                       Nora Ada Bicet Juan   F  34.0   180.0
# 2177    1214                                Eric Agueh   M  24.0   180.0
# 47715  24603                    Jos Luis D'Andrea Mohr   M  36.0     NaN
# 16043   8638                       Stefano Battistelli   M  22.0   176.0
# 22077  11638                            Michael Binzer   M  23.0   180.0
# ...      ...                                       ...  ..   ...     ...
# 21243  11216                              Bandu Bhosle   M  19.0     NaN
# 45891  23685             Steffen Borries Ocrik Cranmer   M  18.0   180.0
# 42613  21984                             Benoit Clment   M  20.0   178.0
# 43567  22469                           Melissa Collins   F  23.0   165.0
# 68268  34873  Rafael Fernndez de Henostrosa y Salabert   M  28.0     NaN
#
#        Weight           Team  NOC        Games  Year  Season         City  \
# 21410    87.0          Spain  ESP  2012 Summer  2012  Summer       London
# 2177     72.0          Benin  BEN  1996 Summer  1996  Summer      Atlanta
# 47715     NaN      Argentina  ARG  1952 Summer  1952  Summer     Helsinki
# 16043    61.0          Italy  ITA  1992 Summer  1992  Summer    Barcelona
# 22077    73.0        Denmark  DEN  1992 Winter  1992  Winter  Albertville
# ...       ...            ...  ...          ...   ...     ...          ...
# 21243     NaN          India  IND  1964 Summer  1964  Summer        Tokyo
# 45891    67.0  Great Britain  GBR  1952 Summer  1952  Summer     Helsinki
# 42613    70.0         Canada  CAN  1984 Summer  1984  Summer  Los Angeles
# 43567    61.0         Canada  CAN  2000 Summer  2000  Summer       Sydney
# 68268     NaN          Spain  ESP  1924 Summer  1924  Summer        Paris
#
#                       Sport                                              Event
# 21410             Athletics                    Athletics Women's Javelin Throw
# 2177              Athletics               Athletics Men's 4 x 100 metres Relay
# 47715               Fencing                    Fencing Men's Sabre, Individual
# 16043              Swimming      Swimming Men's 4 x 200 metres Freestyle Relay
# 22077  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# ...                     ...                                                ...
# 21243            Gymnastics                             Gymnastics Men's Rings
# 45891              Shooting  Shooting Men's Small-Bore Rifle, Three Positio...
# 42613              Swimming      Swimming Men's 4 x 200 metres Freestyle Relay
# 43567            Water Polo                      Water Polo Women's Water Polo
# 68268                  Polo                                    Polo Men's Polo
#
# [66500 rows x 14 columns]

# %%
y_train
# Out:
#           ID                                      Name Sex   Age  Height  \
# 21410  11300                       Nora Ada Bicet Juan   F  34.0   180.0
# 2177    1214                                Eric Agueh   M  24.0   180.0
# 47715  24603                    Jos Luis D'Andrea Mohr   M  36.0     NaN
# 16043   8638                       Stefano Battistelli   M  22.0   176.0
# 22077  11638                            Michael Binzer   M  23.0   180.0
# ...      ...                                       ...  ..   ...     ...
# 21243  11216                              Bandu Bhosle   M  19.0     NaN
# 45891  23685             Steffen Borries Ocrik Cranmer   M  18.0   180.0
# 42613  21984                             Benoit Clment   M  20.0   178.0
# 43567  22469                           Melissa Collins   F  23.0   165.0
# 68268  34873  Rafael Fernndez de Henostrosa y Salabert   M  28.0     NaN
#
#        Weight           Team  NOC        Games  Year  Season         City  \
# 21410    87.0          Spain  ESP  2012 Summer  2012  Summer       London
# 2177     72.0          Benin  BEN  1996 Summer  1996  Summer      Atlanta
# 47715     NaN      Argentina  ARG  1952 Summer  1952  Summer     Helsinki
# 16043    61.0          Italy  ITA  1992 Summer  1992  Summer    Barcelona
# 22077    73.0        Denmark  DEN  1992 Winter  1992  Winter  Albertville
# ...       ...            ...  ...          ...   ...     ...          ...
# 21243     NaN          India  IND  1964 Summer  1964  Summer        Tokyo
# 45891    67.0  Great Britain  GBR  1952 Summer  1952  Summer     Helsinki
# 42613    70.0         Canada  CAN  1984 Summer  1984  Summer  Los Angeles
# 43567    61.0         Canada  CAN  2000 Summer  2000  Summer       Sydney
# 68268     NaN          Spain  ESP  1924 Summer  1924  Summer        Paris
#
#                       Sport                                              Event
# 21410             Athletics                    Athletics Women's Javelin Throw
# 2177              Athletics               Athletics Men's 4 x 100 metres Relay
# 47715               Fencing                    Fencing Men's Sabre, Individual
# 16043              Swimming      Swimming Men's 4 x 200 metres Freestyle Relay
# 22077  Cross Country Skiing  Cross Country Skiing Men's 10/15 kilometres Pu...
# ...                     ...                                                ...
# 21243            Gymnastics                             Gymnastics Men's Rings
# 45891              Shooting  Shooting Men's Small-Bore Rifle, Three Positio...
# 42613              Swimming      Swimming Men's 4 x 200 metres Freestyle Relay
# 43567            Water Polo                      Water Polo Women's Water Polo
# 68268                  Polo                                    Polo Men's Polo
#
# [66500 rows x 14 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('data.csv')

plt.scatter(data['Height'],data['Weight'])
plt.title('scatter plot')
plt.xlabel('Height')
plt.ylabel('weight')
plt.show()

# %%
import pandas as pd
import matpoltlib.pyplot as plt
df=pd.read_csv('data.csv')
plt.bar(df['Height'],df['Weight'])
plt.title('bar chart')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('data.csv')
plt.hist(df['Height'])
plt.title('Histogram')
plt.show()
